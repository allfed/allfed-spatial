# %%
# Allow access to Python imports from higher level folder
import sys
sys.path.append('..')

# Define directory locations
TEST_DIR = '../test_data/leaves/'

# ALLFED libs
from features.io import write_features, load_features

from collections import defaultdict
import operator

# %%
# Load data
forest = load_features(TEST_DIR + 'forest_regions.shp')
hunger = load_features(TEST_DIR + 'hunger_regions.shp')

# %%
# Iterate through hunger regions and fill out data
hr_length = len(hunger)

for i, hr in enumerate(hunger):
    
    numid = hr.data['NUMID']
    forest_classes_by_area = defaultdict(int)
    forest_classes_by_biomass = defaultdict(int)
    
    for fr in forest:
        if fr.data['NUMID'] == numid:
            forest_class = fr.data['GEZ_TERM']
            forest_classes_by_area[forest_class] += fr.data['area_ha']
            forest_classes_by_biomass[forest_class] += fr.data['l_biomass']   
    
    if len(forest_classes_by_area.keys()) > 0:
        sorted_by_area = sorted(forest_classes_by_area.items(), key=operator.itemgetter(1), reverse=True)
        sorted_by_biomass = sorted(forest_classes_by_biomass.items(), key=operator.itemgetter(1), reverse=True)
        
    else:
        sorted_by_area = {}
        sorted_by_biomass = {}
        
    
    for idx in range(1,4):
        if len(sorted_by_area) < idx:
            hr.update_data('fca{}_key'.format(idx), '')
            hr.update_data('fca{}_val'.format(idx), '')
        else:
            hr.update_data('fca{}_key'.format(idx), sorted_by_area[idx - 1][0])
            hr.update_data('fca{}_val'.format(idx), sorted_by_area[idx - 1][1])
            
        
        if len(sorted_by_biomass) < idx:
            hr.update_data('fcb{}_key'.format(idx), '')
            hr.update_data('fcb{}_val'.format(idx), '')
            
        else:
            hr.update_data('fcb{}_key'.format(idx), sorted_by_biomass[idx - 1][0])
            hr.update_data('fcb{}_val'.format(idx), sorted_by_biomass[idx - 1][1])

# %%
write_features(hunger, TEST_DIR + 'hunger_regions_with_forest_classes.shp')

# %%
uw_pop_by_forest_class_and_country = defaultdict(int)
l_biomass_by_forest_class_and_country = defaultdict(int)
uw_pop_lookup = {hr.data['NUMID']: hr.data['pop_uw'] for hr in hunger}

# %%
for fr in forest:
    forest_class = fr.data['GEZ_TERM'].lower().replace(' ', '-')
    country_code = fr.data['IS03V10']
    uw_pop = uw_pop_lookup.get(fr.data['NUMID'])
    if uw_pop:
        l_biomass_by_forest_class_and_country['{}-{}'.format(country_code, forest_class)] += fr.data['l_biomass']

# %%
import csv

csvData = [['Country-forest-class', 'UW_pop', 'Leaf_biomass']]

for fcc, lb in l_biomass_by_forest_class_and_country.items():
    uwp = uw_pop_lookup.get(fr.data['NUMID'])
    if lb and uwp:
        csvData.append([fcc, uwp, lb])

with open('test.csv', 'w') as csvFile:
    writer = csv.writer(csvFile)
    writer.writerows(csvData)

csvFile.close()

# %%
sorted(forest_classes_by_country_and_biomass.items(), key=operator.itemgetter(1), reverse=True)
# Out:
# [('BRA-tropical-rainforest', 1385316722),
#  ('COD-tropical-rainforest', 630738061),
#  ('IDN-tropical-rainforest', 471420231),
#  ('RUS-boreal-coniferous-forest', 285725876),
#  ('BRA-tropical-moist-deciduous-forest', 228534671),
#  ('PER-tropical-rainforest', 225815957),
#  ('COL-tropical-rainforest', 203679435),
#  ('CHN-subtropical-humid-forest', 191078112),
#  ('AGO-tropical-moist-deciduous-forest', 184044678),
#  ('USA-subtropical-humid-forest', 170159256),
#  ('PNG-tropical-rainforest', 121082613),
#  ('ZMB-tropical-moist-deciduous-forest', 118905876),
#  ('COG-tropical-rainforest', 109324143),
#  ('CAN-boreal-coniferous-forest', 102873606),
#  ('BOL-tropical-rainforest', 102858304),
#  ('VEN-tropical-rainforest', 100634541),
#  ('COD-tropical-moist-deciduous-forest', 97323608),
#  ('GAB-tropical-rainforest', 95450160),
#  ('CAF-tropical-moist-deciduous-forest', 95208474),
#  ('CMR-tropical-rainforest', 89160004),
#  ('MYS-tropical-rainforest', 88379146),
#  ('CAN-boreal-tundra-woodland', 78181231),
#  ('BRA-tropical-dry-forest', 71639315),
#  ('USA-temperate-continental-forest', 65240279),
#  ('MOZ-tropical-moist-deciduous-forest', 59697993),
#  ('SDN-tropical-moist-deciduous-forest', 54728101),
#  ('AUS-tropical-dry-forest', 54324894),
#  ('NGA-tropical-rainforest', 53209719),
#  ('GUY-tropical-rainforest', 51713307),
#  ('IND-tropical-dry-forest', 51444450),
#  ('MEX-tropical-moist-deciduous-forest', 50819527),
#  ('ARG-tropical-dry-forest', 50414137),
#  ('MOZ-tropical-dry-forest', 50226936),
#  ('ARG-tropical-moist-deciduous-forest', 47923552),
#  ('TZA-tropical-moist-deciduous-forest', 46649252),
#  ('PRY-tropical-dry-forest', 44530498),
#  ('AGO-tropical-rainforest', 44298412),
#  ('CIV-tropical-rainforest', 44132408),
#  ('CAF-tropical-rainforest', 43688464),
#  ('BRA-subtropical-humid-forest', 43173190),
#  ('CAN-temperate-continental-forest', 40768445),
#  ('PHL-tropical-rainforest', 39915684),
#  ('BOL-tropical-moist-deciduous-forest', 39410337),
#  ('NGA-tropical-moist-deciduous-forest', 38388172),
#  ('VEN-tropical-moist-deciduous-forest', 36531118),
#  ('MMR-tropical-rainforest', 35273140),
#  ('GIN-tropical-moist-deciduous-forest', 34621874),
#  ('ZWE-tropical-dry-forest', 33398115),
#  ('ECU-tropical-rainforest', 32061831),
#  ('AUS-subtropical-humid-forest', 31387791),
#  ('GUF-tropical-rainforest', 31094767),
#  ('IND-tropical-rainforest', 30719180),
#  ('SUR-tropical-rainforest', 30586930),
#  ('CIV-tropical-moist-deciduous-forest', 29626973),
#  ('CMR-tropical-moist-deciduous-forest', 29608815),
#  ('RUS-temperate-continental-forest', 29183891),
#  ('MEX-tropical-dry-forest', 29125645),
#  ('MMR-tropical-moist-deciduous-forest', 28827515),
#  ('MDG-tropical-rainforest', 28221193),
#  ('AUS-temperate-oceanic-forest', 27953581),
#  ('RUS-boreal-tundra-woodland', 27149478),
#  ('IND-tropical-moist-deciduous-forest', 26719697),
#  ('LBR-tropical-rainforest', 26285768),
#  ('BOL-tropical-dry-forest', 25957764),
#  ('GHA-tropical-moist-deciduous-forest', 24687873),
#  ('TZA-tropical-dry-forest', 23644183),
#  ('AGO-tropical-dry-forest', 22532391),
#  ('ZMB-tropical-dry-forest', 22497512),
#  ('SDN-tropical-dry-forest', 21957253),
#  ('GHA-tropical-rainforest', 21410830),
#  ('ARG-subtropical-humid-forest', 19847607),
#  ('NIC-tropical-rainforest', 19157039),
#  ('CHL-temperate-oceanic-forest', 19129477),
#  ('JPN-subtropical-humid-forest', 18247031),
#  ('THA-tropical-rainforest', 17396914),
#  ('PRY-tropical-moist-deciduous-forest', 17048995),
#  ('FIN-boreal-coniferous-forest', 16383683),
#  ('UGA-tropical-rainforest', 16114685),
#  ('ESP-subtropical-dry-forest', 16093472),
#  ('BEN-tropical-moist-deciduous-forest', 15949820),
#  ('USA-temperate-oceanic-forest', 15588541),
#  ('SUR-tropical-moist-deciduous-forest', 15445825),
#  ('MDG-tropical-moist-deciduous-forest', 15443196),
#  ('CHN-temperate-continental-forest', 15159253),
#  ('ZAF-tropical-dry-forest', 14926209),
#  ('HND-tropical-rainforest', 14715281),
#  ('COL-tropical-moist-deciduous-forest', 14473367),
#  ('BWA-tropical-dry-forest', 14357080),
#  ('GIN-tropical-rainforest', 14112273),
#  ('SWE-boreal-coniferous-forest', 14110946),
#  ('ZAF-subtropical-humid-forest', 13638821),
#  ('MEX-tropical-rainforest', 13249208),
#  ('FRA-temperate-oceanic-forest', 13155485),
#  ('THA-tropical-moist-deciduous-forest', 12994077),
#  ('GUY-tropical-moist-deciduous-forest', 12936559),
#  ('DEU-temperate-oceanic-forest', 12369666),
#  ('LAO-tropical-rainforest', 12205472),
#  ('VNM-tropical-moist-deciduous-forest', 12049363),
#  ('VNM-tropical-rainforest', 11598097),
#  ('AUS-tropical-rainforest', 11400706),
#  ('NZL-subtropical-humid-forest', 10572260),
#  ('NZL-temperate-oceanic-forest', 10066491),
#  ('UGA-tropical-moist-deciduous-forest', 10060964),
#  ('GTM-tropical-rainforest', 9946803),
#  ('AUS-subtropical-dry-forest', 9912306),
#  ('CHL-subtropical-dry-forest', 9894150),
#  ('THA-tropical-dry-forest', 9823524),
#  ('TCD-tropical-moist-deciduous-forest', 9774318),
#  ('URY-subtropical-humid-forest', 9745777),
#  ('PAN-tropical-rainforest', 9281060),
#  ('GNQ-tropical-rainforest', 9228728),
#  ('IDN-tropical-moist-deciduous-forest', 9226277),
#  ('USA-subtropical-dry-forest', 8939146),
#  ('CHN-boreal-coniferous-forest', 8935172),
#  ('ITA-subtropical-dry-forest', 8910254),
#  ('KHM-tropical-dry-forest', 8834558),
#  ('SLE-tropical-rainforest', 8833449),
#  ('TCD-tropical-dry-forest', 8778710),
#  ('LAO-tropical-moist-deciduous-forest', 8318689),
#  ('CAF-tropical-dry-forest', 8127821),
#  ('MWI-tropical-moist-deciduous-forest', 7713619),
#  ('ARG-tropical-rainforest', 7702994),
#  ('TGO-tropical-moist-deciduous-forest', 7654213),
#  ('NAM-tropical-dry-forest', 7616402),
#  ('CRI-tropical-rainforest', 7522892),
#  ('MLI-tropical-moist-deciduous-forest', 7270806),
#  ('USA-boreal-tundra-woodland', 7081962),
#  ('KEN-tropical-moist-deciduous-forest', 6810051),
#  ('TZA-tropical-rainforest', 6787221),
#  ('None-tropical-rainforest', 6773932),
#  ('PHL-tropical-moist-deciduous-forest', 6223400),
#  ('KHM-tropical-moist-deciduous-forest', 6213194),
#  ('DZA-subtropical-dry-forest', 6204249),
#  ('GNB-tropical-moist-deciduous-forest', 6194027),
#  ('PNG-tropical-moist-deciduous-forest', 6192950),
#  ('GTM-tropical-moist-deciduous-forest', 6115314),
#  ('ETH-tropical-dry-forest', 6022715),
#  ('SLE-tropical-moist-deciduous-forest', 5987964),
#  ('MOZ-tropical-rainforest', 5938648),
#  ('ZAF-subtropical-dry-forest', 5862369),
#  ('GRC-subtropical-dry-forest', 5747820),
#  ('KHM-tropical-rainforest', 5634838),
#  ('TUR-subtropical-dry-forest', 5583548),
#  ('PRT-subtropical-dry-forest', 5068292),
#  ('TWN-subtropical-humid-forest', 4908012),
#  ('SEN-tropical-moist-deciduous-forest', 4837430),
#  ('MLI-tropical-dry-forest', 4586756),
#  ('NIC-tropical-moist-deciduous-forest', 4499935),
#  ('VEN-tropical-dry-forest', 4484848),
#  ('CHN-tropical-moist-deciduous-forest', 4402403),
#  ('UKR-temperate-continental-forest', 4371671),
#  ('SDN-tropical-rainforest', 4235939),
#  ('BFA-tropical-moist-deciduous-forest', 4123509),
#  ('PRY-tropical-rainforest', 4045821),
#  ('POL-temperate-continental-forest', 3689251),
#  ('HND-tropical-moist-deciduous-forest', 3660580),
#  ('BFA-tropical-dry-forest', 3639056),
#  ('FRA-subtropical-dry-forest', 3610021),
#  ('CUB-tropical-moist-deciduous-forest', 3438988),
#  ('TGO-tropical-rainforest', 3401578),
#  ('BLR-temperate-continental-forest', 3399374),
#  ('NOR-boreal-coniferous-forest', 3392160),
#  ('ETH-tropical-moist-deciduous-forest', 3324317),
#  ('ESP-temperate-oceanic-forest', 3304579),
#  ('PAN-tropical-moist-deciduous-forest', 3221936),
#  ('MAR-subtropical-dry-forest', 3206516),
#  ('NPL-tropical-rainforest', 3050371),
#  ('ROU-temperate-continental-forest', 3024551),
#  ('LAO-tropical-dry-forest', 3020214),
#  ('GBR-temperate-oceanic-forest', 3001209),
#  ('IRN-subtropical-humid-forest', 2783544),
#  ('PRK-temperate-continental-forest', 2778227),
#  ('BGD-tropical-rainforest', 2720787),
#  ('ARG-temperate-oceanic-forest', 2651249),
#  ('NPL-tropical-moist-deciduous-forest', 2633885),
#  ('BLZ-tropical-rainforest', 2599709),
#  ('LKA-tropical-rainforest', 2512487),
#  ('BEN-tropical-rainforest', 2471934),
#  ('SWE-temperate-continental-forest', 2471724),
#  ('SEN-tropical-dry-forest', 2461440),
#  ('BLZ-tropical-moist-deciduous-forest', 2405898),
#  ('LKA-tropical-moist-deciduous-forest', 2328365),
#  ('HND-tropical-dry-forest', 2311198),
#  ('TUR-subtropical-humid-forest', 2264057),
#  ('CRI-tropical-moist-deciduous-forest', 2231800),
#  ('BRN-tropical-rainforest', 2124193),
#  ('GNB-tropical-rainforest', 2061034),
#  ('POL-temperate-oceanic-forest', 1952389),
#  ('GHA-tropical-dry-forest', 1917103),
#  ('SWZ-tropical-dry-forest', 1891457),
#  ('NGA-tropical-dry-forest', 1846083),
#  ('CUB-tropical-rainforest', 1815183),
#  ('ITA-temperate-oceanic-forest', 1795418),
#  ('DOM-tropical-rainforest', 1770037),
#  ('BGD-tropical-moist-deciduous-forest', 1755957),
#  ('TUN-subtropical-dry-forest', 1675106),
#  ('LKA-tropical-dry-forest', 1640608),
#  ('MWI-tropical-dry-forest', 1635734),
#  ('KOR-temperate-continental-forest', 1587411),
#  ('BGR-temperate-continental-forest', 1551425),
#  ('MMR-tropical-dry-forest', 1527584),
#  ('PRT-temperate-oceanic-forest', 1520547),
#  ('VNM-tropical-dry-forest', 1403645),
#  ('SLV-tropical-moist-deciduous-forest', 1396996),
#  ('COL-tropical-dry-forest', 1347197),
#  ('DOM-tropical-moist-deciduous-forest', 1309228),
#  ('USA-tropical-moist-deciduous-forest', 1303710),
#  ('None-tropical-moist-deciduous-forest', 1297502),
#  ('SCG-temperate-continental-forest', 1249315),
#  ('PNG-tropical-dry-forest', 1230194),
#  ('TLS-tropical-rainforest', 1190572),
#  ('ZAF-tropical-moist-deciduous-forest', 1190300),
#  ('GEO-subtropical-humid-forest', 1184674),
#  ('SOM-tropical-moist-deciduous-forest', 1169702),
#  ('HUN-temperate-continental-forest', 1145458),
#  ('None-subtropical-humid-forest', 1135829),
#  ('IRL-temperate-oceanic-forest', 1084638),
#  ('CZE-temperate-continental-forest', 1070570),
#  ('KEN-tropical-rainforest', 1059058),
#  ('LVA-temperate-continental-forest', 1024107),
#  ('TTO-tropical-rainforest', 1013547),
#  ('CHE-temperate-oceanic-forest', 1005627),
#  ('None-temperate-oceanic-forest', 983031),
#  ('BEL-temperate-oceanic-forest', 981968),
#  ('JAM-tropical-rainforest', 971805),
#  ('KOR-subtropical-humid-forest', 916566),
#  ('LTU-temperate-continental-forest', 882858),
#  ('COG-tropical-dry-forest', 876399),
#  ('BEN-tropical-dry-forest', 838902),
#  ('JPN-temperate-continental-forest', 802632),
#  ('ALB-subtropical-dry-forest', 783040),
#  ('NOR-temperate-oceanic-forest', 773066),
#  ('EST-temperate-continental-forest', 747608),
#  ('VNM-subtropical-humid-forest', 741865),
#  ('ECU-tropical-moist-deciduous-forest', 717257),
#  ('NIC-tropical-dry-forest', 712923),
#  ('TUR-temperate-continental-forest', 706794),
#  ('AUT-temperate-oceanic-forest', 702748),
#  ('SVK-temperate-continental-forest', 701720),
#  ('SWE-temperate-oceanic-forest', 685413),
#  ('BTN-tropical-rainforest', 683660),
#  ('DNK-temperate-oceanic-forest', 672133),
#  ('PRI-tropical-rainforest', 641873),
#  ('NLD-temperate-oceanic-forest', 629210),
#  ('ECU-tropical-dry-forest', 627098),
#  ('SLV-tropical-dry-forest', 619202),
#  ('DEU-temperate-continental-forest', 616963),
#  ('MKD-subtropical-dry-forest', 596781),
#  ('None-tropical-dry-forest', 587937),
#  ('HTI-tropical-rainforest', 581270),
#  ('HRV-temperate-continental-forest', 554219),
#  ('CMR-tropical-dry-forest', 534336),
#  ('CYP-subtropical-dry-forest', 522417),
#  ('HRV-subtropical-dry-forest', 485629),
#  ('None-subtropical-dry-forest', 467371),
#  ('COD-tropical-dry-forest', 463114),
#  ('SYR-subtropical-dry-forest', 460978),
#  ('AUT-temperate-continental-forest', 429337),
#  ('BDI-tropical-moist-deciduous-forest', 420593),
#  ('GEO-temperate-continental-forest', 417683),
#  ('AZE-temperate-continental-forest', 413058),
#  ('BIH-temperate-continental-forest', 367447),
#  ('LBN-subtropical-dry-forest', 341027),
#  ('GMB-tropical-moist-deciduous-forest', 310360),
#  ('SVN-temperate-continental-forest', 310313),
#  ('PER-tropical-dry-forest', 301868),
#  ('ISL-boreal-coniferous-forest', 296595),
#  ('MDA-temperate-continental-forest', 280855),
#  ('KEN-tropical-dry-forest', 273362),
#  ('BIH-subtropical-dry-forest', 261514),
#  ('CAN-temperate-oceanic-forest', 260052),
#  ('HTI-tropical-moist-deciduous-forest', 247930),
#  ('JAM-tropical-moist-deciduous-forest', 228234),
#  ('SCG-subtropical-dry-forest', 224226),
#  ('MKD-temperate-continental-forest', 217428),
#  ('LBY-subtropical-dry-forest', 208961),
#  ('GTM-tropical-dry-forest', 183964),
#  ('CUB-tropical-dry-forest', 182333),
#  ('None-temperate-continental-forest', 180837),
#  ('GBR-boreal-coniferous-forest', 180702),
#  ('GRC-temperate-continental-forest', 158681),
#  ('FIN-temperate-continental-forest', 144087),
#  ('BGR-subtropical-dry-forest', 140379),
#  ('None-boreal-coniferous-forest', 137091),
#  ('CRI-tropical-dry-forest', 130222),
#  ('KAZ-temperate-continental-forest', 124222),
#  ('LUX-temperate-oceanic-forest', 123585),
#  ('NER-tropical-dry-forest', 115501),
#  ('AZE-subtropical-humid-forest', 107461),
#  ('SLV-tropical-rainforest', 104676),
#  ('PRI-tropical-moist-deciduous-forest', 104045),
#  ('SVN-subtropical-dry-forest', 103228),
#  ('IRN-temperate-continental-forest', 102326),
#  ('LBR-tropical-moist-deciduous-forest', 101858),
#  ('ALB-temperate-continental-forest', 86405),
#  ('GAB-tropical-dry-forest', 86197),
#  ('PAN-tropical-dry-forest', 80300),
#  ('ARM-temperate-continental-forest', 79253),
#  ('ISR-subtropical-dry-forest', 77511),
#  ('GMB-tropical-dry-forest', 72921),
#  ('TGO-tropical-dry-forest', 68936),
#  ('UGA-tropical-dry-forest', 58213),
#  ('None-boreal-tundra-woodland', 51480),
#  ('PSE-subtropical-dry-forest', 46738),
#  ('NOR-temperate-continental-forest', 45951),
#  ('NPL-tropical-dry-forest', 32918),
#  ('TLS-tropical-moist-deciduous-forest', 31029),
#  ('SGP-tropical-rainforest', 21302),
#  ('CHN-tropical-rainforest', 12922),
#  ('CZE-temperate-oceanic-forest', 9811),
#  ('MEX-subtropical-dry-forest', 8576),
#  ('NOR-boreal-tundra-woodland', 5952),
#  ('ARG-subtropical-dry-forest', 3532),
#  ('IDN-tropical-dry-forest', 2994),
#  ('PAK-tropical-moist-deciduous-forest', 1364),
#  ('SMR-subtropical-dry-forest', 1327),
#  ('LIE-temperate-oceanic-forest', 286),
#  ('EST-boreal-coniferous-forest', 65),
#  ('VAT-subtropical-dry-forest', 7),
#  ('AIA-tropical-moist-deciduous-forest', 0),
#  ('AIA-tropical-dry-forest', 0),
#  ('ASM-tropical-rainforest', 0),
#  ('ATG-tropical-moist-deciduous-forest', 0),
#  ('ATG-tropical-dry-forest', 0),
#  ('ATG-tropical-rainforest', 0),
#  ('BHS-tropical-rainforest', 0),
#  ('BHS-tropical-moist-deciduous-forest', 0),
#  ('BRB-tropical-dry-forest', 0),
#  ('COM-tropical-moist-deciduous-forest', 0),
#  ('COK-tropical-rainforest', 0),
#  ('CYM-tropical-moist-deciduous-forest', 0),
#  ('DMA-tropical-dry-forest', 0),
#  ('DMA-tropical-rainforest', 0),
#  ('FJI-tropical-rainforest', 0),
#  ('FLK-temperate-oceanic-forest', 0),
#  ('FRO-boreal-coniferous-forest', 0),
#  ('FSM-tropical-rainforest', 0),
#  ('GGY-temperate-oceanic-forest', 0),
#  ('GIB-subtropical-dry-forest', 0),
#  ('GLP-tropical-moist-deciduous-forest', 0),
#  ('GLP-tropical-dry-forest', 0),
#  ('GLP-tropical-rainforest', 0),
#  ('GRD-tropical-dry-forest', 0),
#  ('GRD-tropical-moist-deciduous-forest', 0),
#  ('GRD-tropical-rainforest', 0),
#  ('GUM-tropical-rainforest', 0),
#  ('IMN-temperate-oceanic-forest', 0),
#  ('JEY-temperate-oceanic-forest', 0),
#  ('KIR-tropical-rainforest', 0),
#  ('KNA-tropical-moist-deciduous-forest', 0),
#  ('KNA-tropical-rainforest', 0),
#  ('KNA-tropical-dry-forest', 0),
#  ('LCA-tropical-moist-deciduous-forest', 0),
#  ('LCA-tropical-dry-forest', 0),
#  ('LCA-tropical-rainforest', 0),
#  ('MCO-subtropical-dry-forest', 0),
#  ('MDV-tropical-rainforest', 0),
#  ('MHL-tropical-rainforest', 0),
#  ('MLT-subtropical-dry-forest', 0),
#  ('MNP-tropical-rainforest', 0),
#  ('MSR-tropical-dry-forest', 0),
#  ('MSR-tropical-rainforest', 0),
#  ('MSR-tropical-moist-deciduous-forest', 0),
#  ('MTQ-tropical-moist-deciduous-forest', 0),
#  ('MTQ-tropical-rainforest', 0),
#  ('MTQ-tropical-dry-forest', 0),
#  ('MYT-tropical-moist-deciduous-forest', 0),
#  ('NCL-tropical-rainforest', 0),
#  ('NIU-tropical-rainforest', 0),
#  ('NRU-tropical-rainforest', 0),
#  ('PLW-tropical-rainforest', 0),
#  ('PYF-tropical-rainforest', 0),
#  ('REU-tropical-moist-deciduous-forest', 0),
#  ('SLB-tropical-rainforest', 0),
#  ('SPM-boreal-coniferous-forest', 0),
#  ('STP-tropical-rainforest', 0),
#  ('SYC-tropical-moist-deciduous-forest', 0),
#  ('TCA-tropical-rainforest', 0),
#  ('TCA-tropical-moist-deciduous-forest', 0),
#  ('TON-tropical-rainforest', 0),
#  ('TUV-tropical-rainforest', 0),
#  ('UMI-tropical-rainforest', 0),
#  ('USA-tropical-rainforest', 0),
#  ('USA-tropical-dry-forest', 0),
#  ('VCT-tropical-rainforest', 0),
#  ('VCT-tropical-moist-deciduous-forest', 0),
#  ('VGB-tropical-rainforest', 0),
#  ('VGB-tropical-dry-forest', 0),
#  ('VIR-tropical-dry-forest', 0),
#  ('VIR-tropical-rainforest', 0),
#  ('VIR-tropical-moist-deciduous-forest', 0),
#  ('VUT-tropical-rainforest', 0),
#  ('WLF-tropical-rainforest', 0),
#  ('WSM-tropical-rainforest', 0),
#  ('XPF-tropical-moist-deciduous-forest', 0),
#  ('XPG-tropical-rainforest', 0)]
